# %%
import cv2
import tensorflow as tf

CATEGORIES = ["Dog", "Cat"]

def prepare(filepath):
    IMG_SIZE = 50
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

model = tf.keras.models.load_model("64x3-CNN.model")

prediction = model.predict([prepare('cute-kittens.jpg')])
print(CATEGORIES[int(prediction[0][0])])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ce337beb88b8> in <module>()
#       1 import cv2
# ----> 2 import tensorflow as tf
#       3
#       4 CATEGORIES = ["Dog", "Cat"]
#       5
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>()
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 try:
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      86 # Bring in subpackages.
#      87 from tensorflow.python import data
# ---> 88 from tensorflow.python import keras
#      89 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      90 from tensorflow.python.layers import layers
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py in <module>()
#      22 from __future__ import print_function
#      23
# ---> 24 from tensorflow.python.keras import activations
#      25 from tensorflow.python.keras import applications
#      26 from tensorflow.python.keras import backend
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\keras\activations.py in <module>()
#      21 import six
#      22
# ---> 23 from tensorflow.python.keras import backend as K
#      24 from tensorflow.python.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.ops import math_ops
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in <module>()
#      44 from tensorflow.python.ops import functional_ops
#      45 from tensorflow.python.ops import gradients as gradients_module
# ---> 46 from tensorflow.python.ops import image_ops
#      47 from tensorflow.python.ops import init_ops
#      48 from tensorflow.python.ops import linalg_ops
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops.py in <module>()
#      27 # pylint: disable=wildcard-import
#      28 from tensorflow.python.ops.gen_image_ops import *
# ---> 29 from tensorflow.python.ops.image_ops_impl import *
#      30 # pylint: enable=wildcard-import
#      31
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\ops\image_ops_impl.py in <module>()
#      40 from tensorflow.python.util.tf_export import tf_export
#      41
# ---> 42 ops.NotDifferentiable('RandomCrop')
#      43 # TODO(b/31222613): This op may be differentiable, and there may be
#      44 # latent bugs here.
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in NotDifferentiable(op_type)
#    2445   if not isinstance(op_type, six.string_types):
#    2446     raise TypeError("op_type must be a string")
# -> 2447   _gradient_registry.register(None, op_type)
#    2448
#    2449
#
# C:\Users\rahul\Anaconda3\lib\site-packages\tensorflow\python\framework\registry.py in register(self, candidate, name)
#      65     # stack trace is [this_function, Register(), user_function,...]
#      66     # so the user function is #2.
# ---> 67     stack = traceback.extract_stack()
#      68     self._registry[name] = {_TYPE_TAG: candidate, _LOCATION_TAG: stack[2]}
#      69
#
# C:\Users\rahul\Anaconda3\lib\traceback.py in extract_stack(f, limit)
#     205     if f is None:
#     206         f = sys._getframe().f_back
# --> 207     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     208     stack.reverse()
#     209     return stack
#
# C:\Users\rahul\Anaconda3\lib\traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     356         if lookup_lines:
#     357             for f in result:
# --> 358                 f.line
#     359         return result
#     360
#
# C:\Users\rahul\Anaconda3\lib\traceback.py in line(self)
#     280     def line(self):
#     281         if self._line is None:
# --> 282             self._line = linecache.getline(self.filename, self.lineno).strip()
#     283         return self._line
#     284
#
# C:\Users\rahul\Anaconda3\lib\linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# C:\Users\rahul\Anaconda3\lib\linecache.py in getlines(filename, module_globals)
#      45
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#      49         clearcache()
#
# C:\Users\rahul\Anaconda3\lib\linecache.py in updatecache(filename, module_globals)
#     134             return []
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#     138     except OSError:
#
# C:\Users\rahul\Anaconda3\lib\tokenize.py in open(filename)
#     450     detect_encoding().
#     451     """
# --> 452     buffer = _builtin_open(filename, 'rb')
#     453     try:
#     454         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:

# %%
prediction = model.predict([prepare('download.jpg')])
print(CATEGORIES[int(prediction[0][0])])
# Out:
# Dog
